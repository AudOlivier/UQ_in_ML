# %%
import tensorflow as tf
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
a = tf.Variable(initial_value = 2.) #equivalent to weights
b = tf.Variable(initial_value = 1.) #equivalent to rhos
cost = 0.5 * tf.square(2. - a - b)
opt = tf.train.GradientDescentOptimizer(learning_rate=0.01)
grads_and_vars = opt.compute_gradients(cost, [a, b])
grad_step = opt.apply_gradients(grads_and_vars)

with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    print(sess.run(cost))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print(sess.run(cost))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print(sess.run(cost))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print(sess.run(cost))
# Out:
# 0.5
# [(0.98, 1.99), (0.98, 0.99)]
# 0.48020002
# [(0.96040004, 1.9802), (0.96040004, 0.9802)]
# 0.4611841
# [(0.9411921, 1.9705961), (0.9411921, 0.970596)]
# 0.44292128

# %%
a = tf.Variable(initial_value = 2.) #equivalent to weights
b = tf.Variable(initial_value = 1.) #equivalent to rhos
cost = 0.5 * tf.square(2. - a - b)
opt = tf.train.GradientDescentOptimizer(learning_rate=0.01)
grads_and_vars = opt.compute_gradients(cost, a)
grad_step = opt.apply_gradients(grads_and_vars)

with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    print(sess.run(cost))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print(sess.run(cost))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print(sess.run(cost))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print(sess.run(cost))
# Out:
# 0.5
# [(0.99, 1.99)]
# 0.49005002
# [(0.98010004, 1.9801)]
# 0.48029804
# [(0.970299, 1.970299)]
# 0.47074008

# %% [markdown]
# a = b * eps <br>
# cost = 1/2 * (2 - a - b)**2 <br>
# dcost_db = a+b-2, dcost_da = a+b-2, da_db = eps <br>
# dE[cost]_db = E[dcost_da da_db+dcost_db] = sum_over_samples(dcost_da da_db+dcost_db) = sum_over_samples((a+b-2)*eps+a+b-2) <br>

# %%
a = tf.Variable(initial_value = 2.) #equivalent to weights
b = tf.Variable(initial_value = 1.) #equivalent to rhos
eps = tf.Variable(initial_value = [1.])
eps_ = tf.assign(eps, tf.random_normal(shape=(1,), mean=0.0, stddev=0.01, dtype='float32'))
a = b * eps_
cost = 0.5 * tf.square(2. - a - b)
opt = tf.train.GradientDescentOptimizer(learning_rate=0.01)
grads_and_vars = opt.compute_gradients(cost, b)
grad_step = opt.apply_gradients(grads_and_vars)

with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    print(sess.run(cost))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print('eps:')
    print(eps.eval())
    print(sess.run(eps))
    print(sess.run(b))
    print(sess.run(b))
    print(((b*(eps+1)-2)*(eps+1)).eval())
    print(grads)
    print(grads)
    #print('cost {}'.format(sess.run(cost)[0]))
    #print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run(eps))
    print(sess.run(eps))
    print(sess.run(b))
    print(sess.run(b))
    print(((b*(eps+1)-2)*(eps+1)).eval())
    print(sess.run((b*(eps+1)-2)*(eps+1)))
    print(sess.run((b*(eps+1)-2)))
    print(sess.run((b*(eps+1)-2)))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run(eps))
    print(sess.run(eps))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
    
    sess.run(grad_step)
    grads = sess.run(grads_and_vars)
    print(grads)
    print('cost {}'.format(sess.run(cost)[0]))
    print(sess.run((a+b-2.)*eps+(a+b-2.)))
    print(b.eval())
# Out:
# [0.49656317]
# eps:
# [0.00572626]
# [0.00572626]
# 1.01
# 1.01
# [-0.9898524]
# [(-0.9898523, 1.01)]
# [(-0.9898523, 1.01)]
# [0.00572626]
# [0.00572626]
# 1.01
# 1.01
# [-0.9898524]
# [-0.9898524]
# [-0.9842166]
# [-0.9842166]
# [(-0.98011804, 1.0198864)]
# cost 0.4764212965965271
# [0.0038995]
# [0.0038995]
# [-0.98039925]
# [(-0.97068655, 1.0296829)]
# cost 0.45949143171310425
# [-0.9691391]
# [(-0.961134, 1.0393846)]
# cost 0.47224774956703186
# [-0.96085507]
# 1.0393846
# [(-0.9516878, 1.0489969)]
# cost 0.448454886674881
# [-0.9497353]
# 1.0489969
# [(-0.93874186, 1.0585035)]
# cost 0.4411275088787079
# [-0.94082385]
# 1.0585035
# [(-0.9338707, 1.0679133)]
# cost 0.4257662296295166
# [-0.9311653]
# 1.0679133
# [(-0.92582387, 1.0772135)]
# cost 0.4189910590648651
# [-0.92336434]
# 1.0772135
# [(-0.9145112, 1.0864598)]
# cost 0.4049031138420105
# [-0.9139391]
# 1.0864598
# [(-0.90430033, 1.0955917)]
# cost 0.4050286114215851
# [-0.9050957]
# 1.0955917
# [(-0.89959, 1.104622)]
# cost 0.38786569237709045
# [-0.89456177]
# 1.104622
# [(-0.88066417, 1.1135716)]
# cost 0.3942241668701172
# [-0.88612974]
# 1.1135716
# [(-0.87516123, 1.1224654)]
# cost 0.3999902904033661
# [-0.8750949]
# 1.1224654
